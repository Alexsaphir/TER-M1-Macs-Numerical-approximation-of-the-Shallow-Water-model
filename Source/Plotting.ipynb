# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
import pylab as p
#import matplotlib.axes3d as p3
import mpl_toolkits.mplot3d.axes3d as p3
#%matplotlib notebook

# %%
file = 'S:\\Github\\build-TER_New-Desktop_Qt_5_10_1_MinGW_32bit-Release\\Burgers.csv'

# %%
file = 'S:\\Github\\build-TER_New-Desktop_Qt_5_10_1_MinGW_32bit-Release\\LF0.csv'
fileV = 'S:\\Github\\build-TER_New-Desktop_Qt_5_10_1_MinGW_32bit-Release\\LF0_V.csv'

# %%
file = 'S:\\Github\\build-TER_New-Desktop_Qt_5_10_1_MinGW_32bit-Release\\LFSV.csv'
fileV = 'S:\\Github\\build-TER_New-Desktop_Qt_5_10_1_MinGW_32bit-Release\\LFSV_V.csv'
fileZ = 'S:\\Github\\build-TER_New-Desktop_Qt_5_10_1_MinGW_32bit-Release\\LFSV_Z.csv'

# %%
file1 = 'S:\\Github\\build-TER_New-Desktop_Qt_5_10_1_MinGW_32bit-Release\\LFSV2.csv'
fileV1 = 'S:\\Github\\build-TER_New-Desktop_Qt_5_10_1_MinGW_32bit-Release\\LFSV2_V.csv'
fileZ1 = 'S:\\Github\\build-TER_New-Desktop_Qt_5_10_1_MinGW_32bit-Release\\LFSV2_Z.csv'

# %%
file = 'S:\\Github\\build-TER_New-Desktop_Qt_5_10_1_MinGW_32bit-Debug\\LFSV2.csv'
fileV = 'S:\\Github\\build-TER_New-Desktop_Qt_5_10_1_MinGW_32bit-Debug\\LFSV2_V.csv'

# %%
spZ = np.loadtxt(fileZ, delimiter=' ')
spZ1 = np.loadtxt(fileZ1, delimiter=' ')

# %%
N=128
sp = np.loadtxt(file, delimiter=' ')


xx = np.linspace(-10,10, sp.shape[1])
tt = np.linspace(0,1, sp.shape[0])
X,T = np.meshgrid(xx, tt)

plt.contourf(X, T, sp, N)
plt.grid(True,color='black')
plt.ylabel('t')
plt.xlabel('x')
plt.colorbar()
plt.show()

# %%
spV = np.loadtxt(fileV,  delimiter=' ')

plt.contourf(X, T, spV, N)
plt.grid(True,color='black')
plt.ylabel('t')
plt.xlabel('x')
plt.colorbar()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
tt.shape

# %%
101*.15

# %%
sp[1,:].shape
# Out:
# (401,)

# %%
# %matplotlib notebook

# %%
fig=p.figure()
ax = p3.Axes3D(fig)
#ax.plot_wireframe
ax.plot_surface(X,T,sp,cmap=cm.plasma)
p.contour(X,T,sp)
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
p.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
spV = np.loadtxt(fileV,  delimiter=' ')
sp = np.loadtxt(file, delimiter=' ')
spZ = np.loadtxt(fileZ, delimiter=' ')

spZ1 = np.loadtxt(fileZ1, delimiter=' ')

spV1 = np.loadtxt(fileV1,  delimiter=' ')
sp1 = np.loadtxt(file1, delimiter=' ')


xx = np.linspace(-10,10, sp.shape[1])
tt = np.linspace(0,1, sp.shape[0])

xx1 = np.linspace(-10,10, sp1.shape[1])
tt1 = np.linspace(0,1, sp1.shape[0])

i = tt.size - 1
i1 = tt1.size - 1

plt.axes().set_aspect(aspect=.5)
plt.subplots_adjust(hspace=.7)

plt.subplot(211)
plt.plot(xx, sp[i])
plt.plot(xx, sp[0], 'r--')
plt.plot(xx, spZ, 'black')


plt.xlabel('x')
plt.ylabel('u')
plt.legend(["u(x,t=" + str(tt[i]) +"), N=" + str(sp[i].size), "u(x,t=0)"])
plt.title("Scheme of order 1")

plt.subplot(212)
plt.plot(xx1, sp1[i1])
plt.plot(xx1, sp1[0], 'r--')
plt.plot(xx1, spZ1, 'black')


plt.xlabel('x')
plt.ylabel('v')
plt.legend(["u(x,t=" + str(tt1[i1]) +"), N=" + str(sp1[i1].size), "u(x,t=0)"])
plt.title("Scheme of order 2")
# Out:
# <img src="data:image/png;base64,..." width="826">
# Text(0.5,1,'Scheme of order 2')

# %%
fig=p.figure()
ax = p3.Axes3D(fig)
#ax.plot_wireframe
ax.plot_surface(X,T,spV,cmap=cm.plasma)
p.contour(X,T,sp)
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
p.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-bdc38241a4f8> in <module>()
#       2 ax = p3.Axes3D(fig)
#       3 #ax.plot_wireframe
# ----> 4 ax.plot_surface(X,T,spV,cmap=cm.plasma)
#       5 p.contour(X,T,sp)
#       6 ax.set_xlabel('X')
#
# NameError: name 'spV' is not defined

# %%
# %matplotlib inline

# %%
spV = np.loadtxt(fileV,  delimiter=' ')
sp = np.loadtxt(file, delimiter=' ')
spZ = np.loadtxt(fileZ, delimiter=' ')

spZ1 = np.loadtxt(fileZ1, delimiter=' ')

spV1 = np.loadtxt(fileV1,  delimiter=' ')
sp1 = np.loadtxt(file1, delimiter=' ')


xx = np.linspace(0,1, sp.shape[1])
tt = np.linspace(0,1, sp.shape[0])

xx1 = np.linspace(0,1, sp1.shape[1])
tt1 = np.linspace(0,1, sp1.shape[0])

X,T = np.meshgrid(xx, tt)
X1,T1 = np.meshgrid(xx1, tt1)

i = tt.size - 1
i1 = tt1.size - 1

plt.axes().set_aspect(aspect=.5)
plt.subplots_adjust(hspace=.7)

plt.subplot(211)
plt.contourf(X, T, sp, N)
plt.grid(True,color='black')
plt.colorbar()

plt.xlabel('x')
plt.ylabel('u')
plt.legend(["u(x,t=" + str(tt[i]) +"), N=" + str(sp[i].size), "u(x,t=0)"])
plt.title("Scheme of order 1")

plt.subplot(212)
plt.contourf(X1, T1, sp1, N)
plt.grid(True,color='black')
plt.colorbar()


plt.xlabel('x')
plt.ylabel('v')
plt.legend(["u(x,t=" + str(tt1[i1]) +"), N=" + str(sp1[i1].size), "u(x,t=0)"])
plt.title("Scheme of order 2")
# Out:
# <img src="data:image/png;base64,..." width="975">
# Text(0.5,1,'Scheme of order 2')
